# %% [markdown]
# # AST 7939 Week 5

# %% [markdown]
# ## Regression methods

# %% [markdown]
# ### [Regression with DT](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html)

# %%
import numpy as np

# Quadratic training set + noise
np.random.seed(42)
m = 200
X = np.random.rand(m, 1)
y = 4 * (X - 0.5) ** 2
y = y + np.random.randn(m, 1) / 10

# %%
import matplotlib.pyplot as plt 

plt.scatter(X,y)

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor(max_depth=2, random_state=42)
tree_reg.fit(X, y)
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt

tree_reg1 = DecisionTreeRegressor(random_state=42, max_depth=2)
tree_reg2 = DecisionTreeRegressor(random_state=42, max_depth=3)

tree_reg1.fit(X, y)
tree_reg2.fit(X, y)

def plot_regression_predictions(tree_reg, X, y, axes=[0, 1, -0.2, 1], ylabel="$y$"):
    x1 = np.linspace(axes[0], axes[1], 500).reshape(-1, 1)
    y_pred = tree_reg.predict(x1)
    plt.axis(axes)
    plt.xlabel("$x_1$", fontsize=18)
    if ylabel:
        plt.ylabel(ylabel, fontsize=18, rotation=0)
    plt.plot(X, y, "b.")
    plt.plot(x1, y_pred, "r.-", linewidth=2, label=r"$\hat{y}$")

fig, axes = plt.subplots(ncols=2, figsize=(10, 4), sharey=True)

plt.sca(axes[0])
plot_regression_predictions(tree_reg1, X, y)
for split, style in ((0.1973, "k-"), (0.0917, "k--"), (0.7718, "k--")):
    plt.plot([split, split], [-0.2, 1], style, linewidth=2)
plt.text(0.21, 0.65, "Depth=0", fontsize=15)
plt.text(0.01, 0.2, "Depth=1", fontsize=13)
plt.text(0.65, 0.8, "Depth=1", fontsize=13)
plt.legend(loc="upper center", fontsize=18)
plt.title("max_depth=2", fontsize=14)

plt.sca(axes[1])
plot_regression_predictions(tree_reg2, X, y, ylabel=None)
for split, style in ((0.1973, "k-"), (0.0917, "k--"), (0.7718, "k--")):
    plt.plot([split, split], [-0.2, 1], style, linewidth=2)
for split in (0.0458, 0.1298, 0.2873, 0.9040):
    plt.plot([split, split], [-0.2, 1], "k:", linewidth=1)
plt.text(0.3, 0.5, "Depth=2", fontsize=13)
plt.title("max_depth=3", fontsize=14)
# Out:
# Text(0.5, 1.0, 'max_depth=3')

# %%
tree_reg1.predict([[0.5]])
# Out:
# array([0.11063973])

# %%
tree_reg1 = DecisionTreeRegressor(random_state=42)
tree_reg2 = DecisionTreeRegressor(random_state=42, min_samples_leaf=10)
tree_reg1.fit(X, y)
tree_reg2.fit(X, y)

x1 = np.linspace(0, 1, 500).reshape(-1, 1)
y_pred1 = tree_reg1.predict(x1)
y_pred2 = tree_reg2.predict(x1)

fig, axes = plt.subplots(ncols=2, figsize=(10, 4), sharey=True)

plt.sca(axes[0])
plt.plot(X, y, "b.")
plt.plot(x1, y_pred1, "r.-", linewidth=2, label=r"$\hat{y}$")
plt.axis([0, 1, -0.2, 1.1])
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", fontsize=18, rotation=0)
plt.legend(loc="upper center", fontsize=18)
plt.title("No restrictions", fontsize=14)

plt.sca(axes[1])
plt.plot(X, y, "b.")
plt.plot(x1, y_pred2, "r.-", linewidth=2, label=r"$\hat{y}$")
plt.axis([0, 1, -0.2, 1.1])
plt.xlabel("$x_1$", fontsize=18)
plt.title("min_samples_leaf={}".format(tree_reg2.min_samples_leaf), fontsize=14)
# Out:
# Text(0.5, 1.0, 'min_samples_leaf=10')

# %% [markdown]
# ### [Regression with kNN](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import neighbors

np.random.seed(0)
X = np.sort(5 * np.random.rand(40, 1), axis=0)
T = np.linspace(0, 5, 500)[:, np.newaxis]
y = np.sin(X).ravel()

# Add noise
y[::5] += 1 * (0.5 - np.random.rand(8))

# %%
n_neighbors = 5

for i, weights in enumerate(["uniform", "distance"]):
    knn = neighbors.KNeighborsRegressor(n_neighbors, weights=weights)
    knn.fit(X, y)
    y_ = knn.predict(T)
    
    plt.subplot(2, 1, i + 1)
    plt.scatter(X, y, color="darkorange", label="data")
    plt.plot(T, y_, color="navy", label="prediction")
    plt.axis("tight")
    plt.legend()
    plt.title("KNeighborsRegressor (k = %i, weights = '%s')" % (n_neighbors, weights))

plt.tight_layout()
plt.show()

# %%
knn.predict([[1.5]])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/cg/bgcbwqb93r90b43wcwfxnth40000gp/T/ipykernel_25682/2956058603.py in <module>
# ----> 1 knn.predict([[1.5]])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_regression.py in predict(self, X)
#     238             y_pred = np.mean(_y[neigh_ind], axis=1)
#     239         else:
# --> 240             y_pred = np.empty((X.shape[0], _y.shape[1]), dtype=np.float64)
#     241             denom = np.sum(weights, axis=1)
#     242
#
# AttributeError: 'list' object has no attribute 'shape'

# %% [markdown]
# ### [Regression with SVM](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVR.html)

# %% [markdown]
# ### Here's an example of linear SVR.

# %%
np.random.seed(42)
m = 50
X = 2 * np.random.rand(m, 1)
y = (4 + 3 * X + np.random.randn(m, 1)).ravel()

# %%
plt.scatter(X, y)

# %%
from sklearn.svm import LinearSVR

# You need to specify desired epsilon.
# Here, I'm making two linear SVR models, one with epsilon=1.5 and the other with epsilon=0.5.

svm_reg1 = LinearSVR(epsilon=1.5, random_state=42)
svm_reg2 = LinearSVR(epsilon=0.5, random_state=42)
svm_reg1.fit(X, y)
svm_reg2.fit(X, y)

# To visualize the support vectors.
def find_support_vectors(svm_reg, X, y):
    y_pred = svm_reg.predict(X)
    off_margin = (np.abs(y - y_pred) >= svm_reg.epsilon)
    return np.argwhere(off_margin)

svm_reg1.support_ = find_support_vectors(svm_reg1, X, y)
svm_reg2.support_ = find_support_vectors(svm_reg2, X, y)

eps_x1 = 1
eps_y_pred = svm_reg1.predict([[eps_x1]])

# %%
def plot_svm_regression(svm_reg, X, y, axes):
    x1s = np.linspace(axes[0], axes[1], 100).reshape(100, 1)
    y_pred = svm_reg.predict(x1s)
    plt.plot(x1s, y_pred, "k-", linewidth=2, label=r"$\hat{y}$")
    plt.plot(x1s, y_pred + svm_reg.epsilon, "k--")
    plt.plot(x1s, y_pred - svm_reg.epsilon, "k--")
    plt.scatter(X[svm_reg.support_], y[svm_reg.support_], s=180, facecolors='#FFAAAA')
    plt.plot(X, y, "bo")
    plt.xlabel(r"$x_1$", fontsize=18)
    plt.axis(axes)

fig, axes = plt.subplots(ncols=2, figsize=(10, 4), sharey=True)

plt.sca(axes[0])
plot_svm_regression(svm_reg1, X, y, [0, 2, 3, 11])
plt.title(r"$\epsilon = {}$".format(svm_reg1.epsilon), fontsize=18)
plt.ylabel(r"$y$", fontsize=18, rotation=0)
plt.annotate(
        '', xy=(eps_x1, eps_y_pred), xycoords='data',
        xytext=(eps_x1, eps_y_pred - svm_reg1.epsilon),
        textcoords='data', arrowprops={'arrowstyle': '<->', 'linewidth': 1.5}
    )
plt.text(0.85, 5.5, r"$\epsilon$", fontsize=20)
plt.sca(axes[1])
plot_svm_regression(svm_reg2, X, y, [0, 2, 3, 11])
plt.title(r"$\epsilon = {}$".format(svm_reg2.epsilon), fontsize=18)
# Out:
# Text(0.5, 1.0, '$\\epsilon = 0.5$')

# %% [markdown]
# ### And here's an example of non-linear SVR

# %%
X = np.sort(5 * np.random.rand(40, 1), axis=0)
y = np.sin(X).ravel()
# Add noise
y[::5] += 3 * (0.5 - np.random.rand(8))

# %%
plt.scatter(X, y)

# %%
from sklearn.svm import SVR

# I'm making three polynomial SVR models.

svm_poly1 = SVR(kernel="poly", degree=1, C=100, epsilon=0.1, coef0=1.)
svm_poly2 = SVR(kernel="poly", degree=2, C=100, epsilon=0.1, coef0=1.)
svm_poly3 = SVR(kernel="poly", degree=3, C=100, epsilon=0.1, coef0=1.)

svm_poly1.fit(X, y)
svm_poly2.fit(X, y)
svm_poly3.fit(X, y)
# Out:
# SVR(C=100, coef0=1.0, kernel='poly')

# %%
fig, axes = plt.subplots(ncols=3, figsize=(15, 4), sharey=True)

plt.sca(axes[0])
plot_svm_regression(svm_poly1, X, y, [0, 5, -1.5, 2.5])
plt.title("First-degree polynomial", fontsize=18)
plt.ylabel(r"$y$", fontsize=18)

plt.sca(axes[1])
plot_svm_regression(svm_poly2, X, y, [0, 5, -1.5, 2.5])
plt.title("Second-degree polynomial", fontsize=18)

plt.sca(axes[2])
plot_svm_regression(svm_poly3, X, y, [0, 5, -1.5, 2.5])
plt.title("Third-degree polynomial", fontsize=18)
# Out:
# Text(0.5, 1.0, 'Third-degree polynomial')

# %% [markdown]
# ### TODO: Hyperparameter optimization
#
# Optimize hyperparameters (C, gamma) for SVR with "rbf" kernel and epsilon=0.1.

# %%
from sklearn.model_selection import GridSearchCV

parameters = [{'gamma': [1e-4, 1e-3, 0.01, 0.1, 1.0, 10.0, 100., 1000.],
               'C': [1, 10, 100, 1000, 10000]}
             ]
svr_gs = GridSearchCV(SVR(kernel='rbf', epsilon=0.1), parameters, cv=5, verbose=3)
svr_gs.fit(X, y)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV 1/5] END ................C=1, gamma=0.0001;, score=-0.044 total time=   0.0s
# [CV 2/5] END ...............C=1, gamma=0.0001;, score=-14.634 total time=   0.0s
# [CV 3/5] END ................C=1, gamma=0.0001;, score=-2.802 total time=   0.0s
# [CV 4/5] END ................C=1, gamma=0.0001;, score=-2.410 total time=   0.0s
# [CV 5/5] END ...............C=1, gamma=0.0001;, score=-27.008 total time=   0.0s
# [CV 1/5] END .................C=1, gamma=0.001;, score=-0.087 total time=   0.0s
# [CV 2/5] END ................C=1, gamma=0.001;, score=-13.209 total time=   0.0s
# [CV 3/5] END .................C=1, gamma=0.001;, score=-3.501 total time=   0.0s
# [CV 4/5] END .................C=1, gamma=0.001;, score=-1.777 total time=   0.0s
# [CV 5/5] END ................C=1, gamma=0.001;, score=-25.083 total time=   0.0s
# [CV 1/5] END ..................C=1, gamma=0.01;, score=-5.549 total time=   0.0s
# [CV 2/5] END ..................C=1, gamma=0.01;, score=-9.015 total time=   0.0s
# [CV 3/5] END ..................C=1, gamma=0.01;, score=-5.164 total time=   0.0s
# [CV 4/5] END ...................C=1, gamma=0.01;, score=0.139 total time=   0.0s
# [CV 5/5] END .................C=1, gamma=0.01;, score=-16.468 total time=   0.0s
# [CV 1/5] END ...................C=1, gamma=0.1;, score=-2.131 total time=   0.0s
# [CV 2/5] END ...................C=1, gamma=0.1;, score=-0.654 total time=   0.0s
# [CV 3/5] END ....................C=1, gamma=0.1;, score=0.495 total time=   0.0s
# [CV 4/5] END ....................C=1, gamma=0.1;, score=0.297 total time=   0.0s
# [CV 5/5] END ...................C=1, gamma=0.1;, score=-0.229 total time=   0.0s
# [CV 1/5] END ....................C=1, gamma=1.0;, score=0.073 total time=   0.0s
# [CV 2/5] END ...................C=1, gamma=1.0;, score=-0.338 total time=   0.0s
# [CV 3/5] END ....................C=1, gamma=1.0;, score=0.589 total time=   0.0s
# [CV 4/5] END ....................C=1, gamma=1.0;, score=0.160 total time=   0.0s
# [CV 5/5] END ...................C=1, gamma=1.0;, score=-7.056 total time=   0.0s
# [CV 1/5] END ..................C=1, gamma=10.0;, score=-0.384 total time=   0.0s
# [CV 2/5] END ..................C=1, gamma=10.0;, score=-0.958 total time=   0.0s
# [CV 3/5] END ..................C=1, gamma=10.0;, score=-3.274 total time=   0.0s
# [CV 4/5] END ..................C=1, gamma=10.0;, score=-0.009 total time=   0.0s
# [CV 5/5] END .................C=1, gamma=10.0;, score=-17.872 total time=   0.0s
# [CV 1/5] END .................C=1, gamma=100.0;, score=-1.277 total time=   0.0s
# [CV 2/5] END ................C=1, gamma=100.0;, score=-16.565 total time=   0.0s
# [CV 3/5] END .................C=1, gamma=100.0;, score=-6.227 total time=   0.0s
# [CV 4/5] END .................C=1, gamma=100.0;, score=-0.341 total time=   0.0s
# [CV 5/5] END ................C=1, gamma=100.0;, score=-20.551 total time=   0.0s
# [CV 1/5] END ................C=1, gamma=1000.0;, score=-1.608 total time=   0.0s
# [CV 2/5] END ...............C=1, gamma=1000.0;, score=-26.142 total time=   0.0s
# [CV 3/5] END ................C=1, gamma=1000.0;, score=-7.505 total time=   0.0s
# [CV 4/5] END ................C=1, gamma=1000.0;, score=-0.584 total time=   0.0s
# [CV 5/5] END ...............C=1, gamma=1000.0;, score=-22.015 total time=   0.0s
# [CV 1/5] END ...............C=10, gamma=0.0001;, score=-0.088 total time=   0.0s
# [CV 2/5] END ..............C=10, gamma=0.0001;, score=-13.220 total time=   0.0s
# [CV 3/5] END ...............C=10, gamma=0.0001;, score=-3.498 total time=   0.0s
# [CV 4/5] END ...............C=10, gamma=0.0001;, score=-1.770 total time=   0.0s
# [CV 5/5] END ..............C=10, gamma=0.0001;, score=-25.080 total time=   0.0s
# [CV 1/5] END ................C=10, gamma=0.001;, score=-6.284 total time=   0.0s
# [CV 2/5] END ...............C=10, gamma=0.001;, score=-10.034 total time=   0.0s
# [CV 3/5] END ................C=10, gamma=0.001;, score=-5.986 total time=   0.0s
# [CV 4/5] END .................C=10, gamma=0.001;, score=0.195 total time=   0.0s
# [CV 5/5] END ...............C=10, gamma=0.001;, score=-16.665 total time=   0.0s
# [CV 1/5] END .................C=10, gamma=0.01;, score=-9.887 total time=   0.0s
# [CV 2/5] END .................C=10, gamma=0.01;, score=-1.908 total time=   0.0s
# [CV 3/5] END .................C=10, gamma=0.01;, score=-0.924 total time=   0.0s
# [CV 4/5] END ..................C=10, gamma=0.01;, score=0.329 total time=   0.0s
# [CV 5/5] END .................C=10, gamma=0.01;, score=-4.236 total time=   0.0s
# [CV 1/5] END ..................C=10, gamma=0.1;, score=-1.764 total time=   0.0s
# [CV 2/5] END ..................C=10, gamma=0.1;, score=-0.463 total time=   0.0s
# [CV 3/5] END ...................C=10, gamma=0.1;, score=0.644 total time=   0.0s
# [CV 4/5] END ...................C=10, gamma=0.1;, score=0.140 total time=   0.0s
# [CV 5/5] END ..................C=10, gamma=0.1;, score=-0.228 total time=   0.0s
# [CV 1/5] END ..................C=10, gamma=1.0;, score=-0.877 total time=   0.0s
# [CV 2/5] END ..................C=10, gamma=1.0;, score=-0.314 total time=   0.0s
# [CV 3/5] END ...................C=10, gamma=1.0;, score=0.086 total time=   0.0s
# [CV 4/5] END ...................C=10, gamma=1.0;, score=0.211 total time=   0.0s
# [CV 5/5] END ..................C=10, gamma=1.0;, score=-2.495 total time=   0.0s
# [CV 1/5] END .................C=10, gamma=10.0;, score=-0.907 total time=   0.0s
# [CV 2/5] END .................C=10, gamma=10.0;, score=-0.584 total time=   0.0s
# [CV 3/5] END .................C=10, gamma=10.0;, score=-4.785 total time=   0.0s
# [CV 4/5] END .................C=10, gamma=10.0;, score=-0.242 total time=   0.0s
# [CV 5/5] END .................C=10, gamma=10.0;, score=-9.293 total time=   0.0s
# [CV 1/5] END ................C=10, gamma=100.0;, score=-1.680 total time=   0.0s
# [CV 2/5] END ...............C=10, gamma=100.0;, score=-18.197 total time=   0.0s
# [CV 3/5] END ................C=10, gamma=100.0;, score=-7.379 total time=   0.0s
# [CV 4/5] END ................C=10, gamma=100.0;, score=-0.247 total time=   0.0s
# [CV 5/5] END ...............C=10, gamma=100.0;, score=-20.185 total time=   0.0s
# [CV 1/5] END ...............C=10, gamma=1000.0;, score=-1.874 total time=   0.0s
# [CV 2/5] END ..............C=10, gamma=1000.0;, score=-27.926 total time=   0.0s
# [CV 3/5] END ...............C=10, gamma=1000.0;, score=-8.166 total time=   0.0s
# [CV 4/5] END ...............C=10, gamma=1000.0;, score=-0.367 total time=   0.0s
# [CV 5/5] END ..............C=10, gamma=1000.0;, score=-21.774 total time=   0.0s
# [CV 1/5] END ..............C=100, gamma=0.0001;, score=-6.363 total time=   0.0s
# [CV 2/5] END .............C=100, gamma=0.0001;, score=-10.146 total time=   0.0s
# [CV 3/5] END ..............C=100, gamma=0.0001;, score=-6.034 total time=   0.0s
# [CV 4/5] END ...............C=100, gamma=0.0001;, score=0.200 total time=   0.0s
# [CV 5/5] END .............C=100, gamma=0.0001;, score=-16.848 total time=   0.0s
# [CV 1/5] END ..............C=100, gamma=0.001;, score=-11.842 total time=   0.0s
# [CV 2/5] END ...............C=100, gamma=0.001;, score=-2.357 total time=   0.0s
# [CV 3/5] END ...............C=100, gamma=0.001;, score=-2.267 total time=   0.0s
# [CV 4/5] END ................C=100, gamma=0.001;, score=0.332 total time=   0.0s
# [CV 5/5] END ...............C=100, gamma=0.001;, score=-9.655 total time=   0.0s
# [CV 1/5] END ................C=100, gamma=0.01;, score=-7.946 total time=   0.0s
# [CV 2/5] END ................C=100, gamma=0.01;, score=-1.569 total time=   0.0s
# [CV 3/5] END .................C=100, gamma=0.01;, score=0.263 total time=   0.0s
# [CV 4/5] END .................C=100, gamma=0.01;, score=0.077 total time=   0.0s
# [CV 5/5] END ................C=100, gamma=0.01;, score=-2.653 total time=   0.0s
# [CV 1/5] END .................C=100, gamma=0.1;, score=-1.897 total time=   0.0s
# [CV 2/5] END .................C=100, gamma=0.1;, score=-0.433 total time=   0.0s
# [CV 3/5] END ..................C=100, gamma=0.1;, score=0.648 total time=   0.0s
# [CV 4/5] END .................C=100, gamma=0.1;, score=-0.056 total time=   0.0s
# [CV 5/5] END .................C=100, gamma=0.1;, score=-0.863 total time=   0.0s
# [CV 1/5] END .................C=100, gamma=1.0;, score=-2.216 total time=   0.0s
# [CV 2/5] END .................C=100, gamma=1.0;, score=-0.468 total time=   0.0s
# [CV 3/5] END .................C=100, gamma=1.0;, score=-0.069 total time=   0.0s
# [CV 4/5] END .................C=100, gamma=1.0;, score=-0.349 total time=   0.0s
# [CV 5/5] END .................C=100, gamma=1.0;, score=-0.433 total time=   0.0s
# [CV 1/5] END ................C=100, gamma=10.0;, score=-5.377 total time=   0.0s
# [CV 2/5] END ................C=100, gamma=10.0;, score=-0.123 total time=   0.0s
# [CV 3/5] END ...............C=100, gamma=10.0;, score=-20.937 total time=   0.0s
# [CV 4/5] END ................C=100, gamma=10.0;, score=-3.665 total time=   0.0s
# [CV 5/5] END ...............C=100, gamma=10.0;, score=-24.671 total time=   0.0s
# [CV 1/5] END ...............C=100, gamma=100.0;, score=-1.680 total time=   0.0s
# [CV 2/5] END ..............C=100, gamma=100.0;, score=-18.197 total time=   0.0s
# [CV 3/5] END ...............C=100, gamma=100.0;, score=-7.379 total time=   0.0s
# [CV 4/5] END ...............C=100, gamma=100.0;, score=-0.247 total time=   0.0s
# [CV 5/5] END ..............C=100, gamma=100.0;, score=-20.185 total time=   0.0s
# [CV 1/5] END ..............C=100, gamma=1000.0;, score=-1.874 total time=   0.0s
# [CV 2/5] END .............C=100, gamma=1000.0;, score=-27.926 total time=   0.0s
# [CV 3/5] END ..............C=100, gamma=1000.0;, score=-8.166 total time=   0.0s
# [CV 4/5] END ..............C=100, gamma=1000.0;, score=-0.367 total time=   0.0s
# [CV 5/5] END .............C=100, gamma=1000.0;, score=-21.774 total time=   0.0s
# [CV 1/5] END ............C=1000, gamma=0.0001;, score=-12.055 total time=   0.0s
# [CV 2/5] END .............C=1000, gamma=0.0001;, score=-2.541 total time=   0.0s
# [CV 3/5] END .............C=1000, gamma=0.0001;, score=-2.577 total time=   0.0s
# [CV 4/5] END ..............C=1000, gamma=0.0001;, score=0.308 total time=   0.0s
# [CV 5/5] END ............C=1000, gamma=0.0001;, score=-10.285 total time=   0.0s
# [CV 1/5] END .............C=1000, gamma=0.001;, score=-11.760 total time=   0.0s
# [CV 2/5] END ..............C=1000, gamma=0.001;, score=-2.025 total time=   0.0s
# [CV 3/5] END ..............C=1000, gamma=0.001;, score=-0.818 total time=   0.0s
# [CV 4/5] END ...............C=1000, gamma=0.001;, score=0.317 total time=   0.0s
# [CV 5/5] END ..............C=1000, gamma=0.001;, score=-3.045 total time=   0.0s
# [CV 1/5] END ...............C=1000, gamma=0.01;, score=-4.628 total time=   0.0s
# [CV 2/5] END ...............C=1000, gamma=0.01;, score=-0.636 total time=   0.0s
# [CV 3/5] END ................C=1000, gamma=0.01;, score=0.435 total time=   0.0s
# [CV 4/5] END ................C=1000, gamma=0.01;, score=0.225 total time=   0.0s
# [CV 5/5] END ...............C=1000, gamma=0.01;, score=-3.300 total time=   0.0s
# [CV 1/5] END ................C=1000, gamma=0.1;, score=-2.904 total time=   0.0s
# [CV 2/5] END ................C=1000, gamma=0.1;, score=-0.385 total time=   0.0s
# [CV 3/5] END .................C=1000, gamma=0.1;, score=0.661 total time=   0.0s
# [CV 4/5] END ................C=1000, gamma=0.1;, score=-0.059 total time=   0.0s
# [CV 5/5] END ................C=1000, gamma=0.1;, score=-0.371 total time=   0.0s
# [CV 1/5] END ...............C=1000, gamma=1.0;, score=-16.020 total time=   0.0s
# [CV 2/5] END ................C=1000, gamma=1.0;, score=-0.674 total time=   0.0s
# [CV 3/5] END ................C=1000, gamma=1.0;, score=-2.181 total time=   0.0s
# [CV 4/5] END ................C=1000, gamma=1.0;, score=-4.173 total time=   0.0s
# [CV 5/5] END ...............C=1000, gamma=1.0;, score=-27.990 total time=   0.0s
# [CV 1/5] END ...............C=1000, gamma=10.0;, score=-5.196 total time=   0.0s
# [CV 2/5] END ................C=1000, gamma=10.0;, score=0.096 total time=   0.0s
# [CV 3/5] END .............C=1000, gamma=10.0;, score=-105.713 total time=   0.0s
# [CV 4/5] END ..............C=1000, gamma=10.0;, score=-49.814 total time=   0.0s
# [CV 5/5] END ..............C=1000, gamma=10.0;, score=-24.540 total time=   0.0s
# [CV 1/5] END ..............C=1000, gamma=100.0;, score=-1.680 total time=   0.0s
# [CV 2/5] END .............C=1000, gamma=100.0;, score=-18.197 total time=   0.0s
# [CV 3/5] END ..............C=1000, gamma=100.0;, score=-7.379 total time=   0.0s
# [CV 4/5] END ..............C=1000, gamma=100.0;, score=-0.247 total time=   0.0s
# [CV 5/5] END .............C=1000, gamma=100.0;, score=-20.185 total time=   0.0s
# [CV 1/5] END .............C=1000, gamma=1000.0;, score=-1.874 total time=   0.0s
# [CV 2/5] END ............C=1000, gamma=1000.0;, score=-27.926 total time=   0.0s
# [CV 3/5] END .............C=1000, gamma=1000.0;, score=-8.166 total time=   0.0s
# [CV 4/5] END .............C=1000, gamma=1000.0;, score=-0.367 total time=   0.0s
# [CV 5/5] END ............C=1000, gamma=1000.0;, score=-21.774 total time=   0.0s
# [CV 1/5] END ...........C=10000, gamma=0.0001;, score=-12.621 total time=   0.0s
# [CV 2/5] END ............C=10000, gamma=0.0001;, score=-2.374 total time=   0.0s
# [CV 3/5] END ............C=10000, gamma=0.0001;, score=-1.919 total time=   0.0s
# [CV 4/5] END .............C=10000, gamma=0.0001;, score=0.311 total time=   0.0s
# [CV 5/5] END ............C=10000, gamma=0.0001;, score=-8.001 total time=   0.0s
# [CV 1/5] END .............C=10000, gamma=0.001;, score=-9.078 total time=   0.0s
# [CV 2/5] END .............C=10000, gamma=0.001;, score=-1.824 total time=   0.0s
# [CV 3/5] END ..............C=10000, gamma=0.001;, score=0.173 total time=   0.0s
# [CV 4/5] END ..............C=10000, gamma=0.001;, score=0.034 total time=   0.0s
# [CV 5/5] END .............C=10000, gamma=0.001;, score=-4.552 total time=   0.0s
# [CV 1/5] END ..............C=10000, gamma=0.01;, score=-1.005 total time=   0.0s
# [CV 2/5] END ..............C=10000, gamma=0.01;, score=-0.030 total time=   0.0s
# [CV 3/5] END ...............C=10000, gamma=0.01;, score=0.579 total time=   0.0s
# [CV 4/5] END ...............C=10000, gamma=0.01;, score=0.282 total time=   0.0s
# [CV 5/5] END ..............C=10000, gamma=0.01;, score=-0.488 total time=   0.0s
# [CV 1/5] END ...............C=10000, gamma=0.1;, score=-0.569 total time=   0.0s
# [CV 2/5] END ...............C=10000, gamma=0.1;, score=-0.318 total time=   0.0s
# [CV 3/5] END ................C=10000, gamma=0.1;, score=0.653 total time=   0.0s
# [CV 4/5] END ................C=10000, gamma=0.1;, score=0.048 total time=   0.0s
# [CV 5/5] END ...............C=10000, gamma=0.1;, score=-0.326 total time=   0.0s
# [CV 1/5] END .............C=10000, gamma=1.0;, score=-770.791 total time=   0.0s
# [CV 2/5] END ...............C=10000, gamma=1.0;, score=-0.849 total time=   0.0s
# [CV 3/5] END ...............C=10000, gamma=1.0;, score=-6.050 total time=   0.0s
# [CV 4/5] END ..............C=10000, gamma=1.0;, score=-56.293 total time=   0.0s
# [CV 5/5] END .............C=10000, gamma=1.0;, score=-377.172 total time=   0.0s
# [CV 1/5] END .............C=10000, gamma=10.0;, score=-37.027 total time=   0.0s
# [CV 2/5] END ...............C=10000, gamma=10.0;, score=0.152 total time=   0.0s
# [CV 3/5] END ............C=10000, gamma=10.0;, score=-187.351 total time=   0.0s
# [CV 4/5] END ..............C=10000, gamma=10.0;, score=-7.966 total time=   0.1s
# [CV 5/5] END .............C=10000, gamma=10.0;, score=-24.432 total time=   0.1s
# [CV 1/5] END .............C=10000, gamma=100.0;, score=-1.680 total time=   0.0s
# [CV 2/5] END ............C=10000, gamma=100.0;, score=-18.197 total time=   0.0s
# [CV 3/5] END .............C=10000, gamma=100.0;, score=-7.379 total time=   0.0s
# [CV 4/5] END .............C=10000, gamma=100.0;, score=-0.247 total time=   0.0s
# [CV 5/5] END ............C=10000, gamma=100.0;, score=-20.185 total time=   0.0s
# [CV 1/5] END ............C=10000, gamma=1000.0;, score=-1.874 total time=   0.0s
# [CV 2/5] END ...........C=10000, gamma=1000.0;, score=-27.926 total time=   0.0s
# [CV 3/5] END ............C=10000, gamma=1000.0;, score=-8.166 total time=   0.0s
# [CV 4/5] END ............C=10000, gamma=1000.0;, score=-0.367 total time=   0.0s
# [CV 5/5] END ...........C=10000, gamma=1000.0;, score=-21.774 total time=   0.0s
# GridSearchCV(cv=5, estimator=SVR(),
#              param_grid=[{'C': [1, 10, 100, 1000, 10000],
#                           'gamma': [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0,
#                                     1000.0]}],
#              verbose=3)

# %%
svr_gs.best_estimator_
# Out:
# SVR(C=10000, gamma=0.1)

# %%
plot_svm_regression(svr_gs.best_estimator_, X, y, [0, 5, -1.5, 2.5])

plt.title("Gaussian RBF (best model)", fontsize=18)
plt.ylabel(r"$y$", fontsize=18, rotation=0)
# Out:
# Text(0, 0.5, '$y$')

# %% [markdown]
# ### TODO (optional): Bitcoin challenge for extra credit?!
#
# Make a regression model and submit your prediction for 2023 March (daily BTC price), by the last day of 2023 February via Canvas. In the first week of 2023 April, I will compute your scores (metric = [mean squared error](https://en.wikipedia.org/wiki/Mean_squared_error)). The winner will get +5 pts in your final homework score. The next three will get +2 pts in your homework score.

# %%
pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: lxml in /Users/lorrainen/opt/anaconda3/lib/python3.9/site-packages (from pandas_datareader) (4.9.1)
# Requirement already satisfied: pandas>=0.23 in /Users/lorrainen/opt/anaconda3/lib/python3.9/site-packages (from pandas_datareader) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /Users/lorrainen/opt/anaconda3/lib/python3.9/site-packages (from pandas_datareader) (2.28.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/lorrainen/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->pandas_datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/lorrainen/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->pandas_datareader) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/lorrainen/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->pandas_datareader) (1.21.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lorrainen/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pandas_datareader) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lorrainen/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pandas_datareader) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/lorrainen/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pandas_datareader) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/lorrainen/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pandas_datareader) (1.26.11)
# Requirement already satisfied: six>=1.5 in /Users/lorrainen/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas_datareader) (1.16.0)
# Installing collected packages: pandas_datareader
# Successfully installed pandas_datareader-0.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pandas-datareader

import pandas_datareader
from pandas_datareader import data

btc = data.DataReader('CBBTCUSD', start='2004', end='2024', data_source="fred")
btc
# Out:
#             CBBTCUSD
# DATE
# 2014-12-01    370.00
# 2014-12-02    378.00
# 2014-12-03    378.00
# 2014-12-04    377.10
# 2014-12-05       NaN
# ...              ...
# 2023-02-08  22973.38
# 2023-02-09  21804.16
# 2023-02-10  21629.58
# 2023-02-11  21857.51
# 2023-02-12  21784.08
#
# [2996 rows x 1 columns]

# %%
btc = btc.dropna()
btc
# Out:
#             CBBTCUSD
# DATE
# 2014-12-01    370.00
# 2014-12-02    378.00
# 2014-12-03    378.00
# 2014-12-04    377.10
# 2014-12-06    378.00
# ...              ...
# 2023-02-08  22973.38
# 2023-02-09  21804.16
# 2023-02-10  21629.58
# 2023-02-11  21857.51
# 2023-02-12  21784.08
#
# [2961 rows x 1 columns]

# %%
plt.plot(btc['CBBTCUSD'])
plt.xlabel('Date')
plt.ylabel('Price [USD]')
# Out:
# Text(0, 0.5, 'Price [USD]')
