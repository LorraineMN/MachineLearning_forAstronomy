# %% [markdown]
# # AST 7939 Homework Assignment #4 (10 pts)

# %% [markdown]
# ## All work is due Wednesday March 22 at 5 pm.
#
# ## Instruction:
# Do all homework in this Jupyter notebook and submit your final .ipynb file via Canvas. Show ALL your work and try to add comment lines as needed to describe what your code does.
#
# You are encouraged to discuss homework problems with your classmates. However, your python script and answers to the questions must be written by yourself.

# %% [markdown]
# ### 1. Clustering (4 pts)

# %% [markdown]
# In this homework problem, we will use DBSCAN to cluster stars in the Orion complex, inspired by [Chen et al. (2020)]( https://ui.adsabs.harvard.edu/abs/2020A%26A...643A.114C/abstract). In that paper, the authors used Shared Nearest Neighbor (SNN), a modified version of DBSCAN, which we did not cover during this course. We will use DBSCAN instead. We will use the same Gaia data set which the authors made publicly available on this Github repository: https://github.com/BoquanErwinChen/GaiaDR2_Orion_Dissection. You can find the data file in the HiPerGator class share folder as well as on Canvas.

# %% [markdown]
# ### Let's read in the Gaia data.

# %%
import pandas as pd

filename = "Orion_data_20190924.csv"
df = pd.read_csv(filename)
df.dropna(subset=['ra', 'dec', 'parallax', 'pmra', 'pmdec'])
df = df.reset_index(drop=True)

# %%
df
# Out:
#               ra  ra_error       dec  dec_error            source_id  \
# 0      75.254413  0.191960 -3.397018   0.139120  3213149215497176960
# 1      75.561670  0.234429 -4.866204   0.206860  3212376190103379584
# 2      75.052364  0.067621 -3.386506   0.052373  3213160421067816320
# 3      75.021177  0.103251 -4.005701   0.078453  3212679487809861248
# 4      75.179643  0.030784 -6.085392   0.026767  3211380620978873344
# ...          ...       ...       ...        ...                  ...
# 29025  89.445830  0.194402  6.615502   0.185320  3321921839250935424
# 29026  89.129035  0.025935  6.574493   0.026383  3322578251987928576
# 29027  89.368736  0.152991  6.784836   0.146842  3322675691910202368
# 29028  89.196556  0.030407  6.698468   0.028375  3322676074163325952
# 29029  89.153266  0.040550  6.611657   0.040266  3322581378724108544
#
#        parallax  parallax_error      pmra  pmra_error     pmdec  ...  \
# 0      2.794918        0.212409 -2.617536    0.408962  1.669195  ...
# 1      3.165823        0.280067 -2.495638    0.511235  0.305570  ...
# 2      2.819880        0.073171  3.840388    0.135597  0.344070  ...
# 3      2.669342        0.123817  0.160382    0.229156 -0.794245  ...
# 4      3.635541        0.038434 -1.479837    0.063476 -1.582998  ...
# ...         ...             ...       ...         ...       ...  ...
# 29025  2.963123        0.234839  3.694528    0.367675 -2.861006  ...
# 29026  2.348265        0.031663 -2.595891    0.048980 -1.927499  ...
# 29027  4.136481        0.186160 -3.831424    0.303003 -2.835496  ...
# 29028  2.695094        0.032618 -3.342518    0.061107 -3.943541  ...
# 29029  2.866548        0.044301 -1.537140    0.079031 -1.950341  ...
#
#        phot_rp_mean_mag     bp_rp  radial_velocity  radial_velocity_error  \
# 0             17.211597  2.672356              NaN                    NaN
# 1             17.622894  2.886185              NaN                    NaN
# 2             15.534090  2.050842              NaN                    NaN
# 3             15.949252  3.309411              NaN                    NaN
# 4              9.450638  0.358518              NaN                    NaN
# ...                 ...       ...              ...                    ...
# 29025         16.974401  2.873224              NaN                    NaN
# 29026         13.123673  1.322178              NaN                    NaN
# 29027         16.644974  2.890482              NaN                    NaN
# 29028         14.011317  1.566079              NaN                    NaN
# 29029         14.380098  1.723124              NaN                    NaN
#
#         teff_val  a_g_val  e_bp_min_rp_val  radius_val   lum_val      ruwe
# 0            NaN      NaN              NaN         NaN       NaN  0.909273
# 1            NaN      NaN              NaN         NaN       NaN  1.033360
# 2      3860.6667   0.2240           0.1140         NaN       NaN  1.001610
# 3            NaN      NaN              NaN         NaN       NaN  0.957134
# 4      8049.0000   0.5495           0.3030         NaN       NaN  1.243121
# ...          ...      ...              ...         ...       ...       ...
# 29025        NaN      NaN              NaN         NaN       NaN  1.022000
# 29026  4863.4053   0.8170           0.4082    0.937234  0.442744  1.047600
# 29027        NaN      NaN              NaN         NaN       NaN  0.997614
# 29028  4465.4100   0.6405           0.3232    0.659014  0.155571  1.015678
# 29029  4103.0000   0.2713           0.1433    0.654139  0.109255  1.088629
#
# [29030 rows x 40 columns]

# %%
df.keys()
# Out:
# Index(['ra', 'ra_error', 'dec', 'dec_error', 'source_id', 'parallax',
#        'parallax_error', 'pmra', 'pmra_error', 'pmdec', 'pmdec_error',
#        'dec_parallax_corr', 'dec_pmdec_corr', 'dec_pmra_corr',
#        'parallax_pmdec_corr', 'parallax_pmra_corr', 'pmra_pmdec_corr',
#        'ra_dec_corr', 'ra_parallax_corr', 'ra_pmra_corr', 'ra_pmdec_corr',
#        'duplicated_source', 'phot_g_mean_flux', 'phot_g_mean_flux_error',
#        'phot_g_mean_mag', 'phot_bp_mean_flux', 'phot_bp_mean_flux_error',
#        'phot_bp_mean_mag', 'phot_rp_mean_flux', 'phot_rp_mean_flux_error',
#        'phot_rp_mean_mag', 'bp_rp', 'radial_velocity', 'radial_velocity_error',
#        'teff_val', 'a_g_val', 'e_bp_min_rp_val', 'radius_val', 'lum_val',
#        'ruwe'],
#       dtype='object')

# %% [markdown]
# ### Spatial distribution of the stars on the sky

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(5,5))

ax.plot(df.ra, df.dec, '.', alpha=0.01)
ax.set_xlim(90,75)
ax.set_aspect('equal')
ax.set_xlabel('RA (deg)')
ax.set_ylabel('Dec (deg)')
# Out:
# Text(0, 0.5, 'Dec (deg)')

# %% [markdown]
# For DBSCAN, there are two hyperparameters to optimize: epsilon & min_samples. We should explore a grid of models to optimize the hyperparameters, but for the sake of computing time let's fix **min_samples = 10** and try to **find a "good" epsilon value**. To do so, let's adopt what has been done in [Castro-Ginard et al. (2018)]( https://ui.adsabs.harvard.edu/abs/2018A%26A...618A..59C/abstract). See their Section 2.2 and Figure 3. To briefly summarize, we generate a random sample having the same number of stars to our dataset (i.e., 29,030), where the features are drawn "randomly". The idea is that, if the stars are all "field stars", not cluster stars, then the distribution of each astrometric parameter would follow normal distribution and would be different from that of cluster stars.

# %% [markdown]
# (a) Among various parameters in the data file, we will use RA, Dec, parallax, RA proper motions RA (pmra), Dec proper motions (pmdec). Make an array containing this information.
#
# Then, generate a new random sample of the same number of stars to the original data, according to the distribution of each astrometric parameter estimated using a Gaussian kernel density estimator. In other words, compute the mean and standard deviation of each of the astrometric parameter of the original data, and generate a random sample which follows a normal (Gaussian) distribution having the computed mean and standard deviation. You can use ```numpy.random.normal``` for this.
#
# DBSCAN requires feature scaling, so apply feature scaling for the two samples (individually). (1 pt)

# %%
import numpy as np

# Put features into array X
X = np.array([df.ra, df.dec, df.parallax, df.pmra, df.pmdec]).T
feature_names = ['RA', 'Dec', 'parallax', 'RA proper motion', 'Dec proper motion'] #this might be helpful for plotting later


# Generate a new random samples
num_stars = len(df.ra) # number of stars in the original data

ra_rand = np.random.normal(np.mean(df.ra), np.std(df.ra), num_stars)
dec_rand = np.random.normal(np.mean(df.dec), np.std(df.dec), num_stars)
parallax_rand = np.random.normal(np.mean(df.parallax), np.std(df.parallax), num_stars)
pmra_rand = np.random.normal(np.mean(df.pmra), np.std(df.pmra), num_stars)
pmdec_rand = np.random.normal(np.mean(df.pmdec), np.std(df.pmdec), num_stars)
# Put the new random samples into an array X_rand
X_rand = np.array([ra_rand, dec_rand, parallax_rand, pmra_rand, pmdec_rand]).T

# %%
X.shape, X_rand.shape
# Out:
# ((29030, 5), (29030, 5))

# %%
# Perform feature scaling
from sklearn.preprocessing import StandardScaler

X_scaled = StandardScaler().fit(X).transform(X)
X_rand_scaled = StandardScaler().fit(X_rand).transform(X_rand)

# %% [markdown]
# (b) For the two samples, compute the distance to the 10th nearest neighbor for each data point (hint: use ```sklearn.neighbors.NearestNeighbors```). Then, make histograms showing the distance to the 10th nearest neighbor. Your plot should look similar to Figure 3 of [Castro-Ginard et al. (2018)]( https://ui.adsabs.harvard.edu/abs/2018A%26A...618A..59C/abstract). If you want to do a statistically more rigorous job, you can draw many random samples (say 100) and take an average of the bootstrapped samples. (1 pt)

# %%
from sklearn import neighbors

# Create a kNN model
model = neighbors.NearestNeighbors(n_neighbors=10)
# Fit to the original data
model.fit(X_scaled)
# Compute distance to the 10 nearest neighbors for each data point
dist, ind = model.kneighbors(X_scaled, n_neighbors=10, return_distance=True)

# dist[0] # distances
# dist[0][:,9].shape #10th nearest neighbor
# nn = dist[0][:,9] #10th nearest neighbor

nn = dist[:,-1] #distance to 10th nearest neighbor

nn.shape
# Out:
# (29030,)

# %%
# Fit to the random sample data
model.fit(X_rand_scaled)
# Compute the distance to the 10 nearest neighbors for each data point
dist, ind = model.kneighbors(X_rand_scaled, n_neighbors=10, return_distance=True)
# distance to 10th nearest neighbor for each data point:
nn_rand = dist[:,-1]

# %% [markdown]
# In the Castro-Ginard (2018) paper, they computed epsilon as the average of the two minimum distances:
#
# $$
# \epsilon = (\epsilon_{kNN}+\epsilon_{rand})/2
# $$
#
# I will attempt to use this same method to choose $\epsilon$,

# %%
# Compute epsilon using the logic above
epsilon = (np.min(nn)+np.min(nn_rand))/2
epsilon
# Out:
# 0.1894166191696245

# %%
counts, bins = np.histogram(nn, bins=50)
plt.stairs(counts, bins, fill=False, color='deepskyblue', label='Original data')

counts, bins = np.histogram(nn_rand, bins=50)
plt.stairs(counts, bins, fill=False, color='orange', label='Random sample')

plt.axvline(epsilon, color='red', label='$\epsilon$ = '+str(epsilon), linestyle='--')

plt.legend()
plt.xlabel('10$^{th}$ Nearest Neighbor Distance')
plt.title('Fig. 1');

# %%
dist = np.sort(nn, axis=0)
plt.plot(dist, '.', label='Original Data', color='deepskyblue')
dist = np.sort(nn_rand, axis=0)
plt.plot(dist, '.', label='Random Sample', color='orange')

plt.axhline(epsilon, color='red', label='$\epsilon$ = '+str(epsilon), linestyle='--')

plt.legend()
plt.ylabel('Distance to 10$^{th}$ nearest neighbor')
plt.title('Fig. 2');

# %% [markdown]
# (c) Based on the histograms you made in (b), what do you think a reasonable epsilon value? Justify your choice. (1 pt)

# %%
# Compute epsilon using the logic from above
epsilon = (np.min(nn)+np.min(nn_rand))/2
epsilon
# Out:
# 0.1894166191696245

# %% [markdown]
# **I think that $\epsilon$ = 0.19 is reasonable based on the histogram because it is close to the peak on the left-most area of the plot where objects are closely clustered together.**

# %% [markdown]
# (d) Using the epsilon you choosed from (c) and min_samples=10, make a DBSCAN model. How many clusters did you find?, and how many menbers do each clusters have? Make a figure showing the distribution of identified clusters. Your figure should look similar to Figure 2 of [Chen et al. (2020)](https://ui.adsabs.harvard.edu/abs/2020A%26A...643A.114C/abstract). (1 pt)

# %%
# Function from week 7 notebook
def plot_dbscan(dbscan, X, size, show_xlabels=True, show_ylabels=True):
    core_mask = np.zeros_like(dbscan.labels_, dtype=bool)
    core_mask[dbscan.core_sample_indices_] = True
    anomalies_mask = dbscan.labels_ == -1 #-1 is label of noise data points
    non_core_mask = ~(core_mask | anomalies_mask)

    cores = dbscan.components_
    anomalies = X[anomalies_mask]
    non_cores = X[non_core_mask]
    
    plt.scatter(cores[:, 0], cores[:, 1],
                c=dbscan.labels_[core_mask], marker='o', s=size, cmap="Paired")
    plt.scatter(cores[:, 0], cores[:, 1], marker='*', s=20, c=dbscan.labels_[core_mask])
    plt.scatter(anomalies[:, 0], anomalies[:, 1],
                c="r", marker="x", s=100, alpha=0.5)
    plt.scatter(non_cores[:, 0], non_cores[:, 1], c=dbscan.labels_[non_core_mask], marker=".")
    if show_xlabels:
        plt.xlabel("$x_1$", fontsize=14)
    else:
        plt.tick_params(labelbottom=False)
    if show_ylabels:
        plt.ylabel("$x_2$", fontsize=14, rotation=0)
    else:
        plt.tick_params(labelleft=False)
    plt.title("eps={:.2f}, min_samples={}".format(dbscan.eps, dbscan.min_samples), fontsize=14)

# %%
from sklearn.cluster import DBSCAN

model = DBSCAN(eps=0.19, min_samples=10)
model.fit(X_scaled)

# Find number of clusters
num_clusters = len(np.unique(model.labels_))-1 #-1 to account for noise group
# Find number of members in each cluster
members = np.bincount(model.labels_+1)

print('Number of clusters = ', num_clusters)
print('Number of members in each cluster (not including noise)= ', members[1:])
# Out:
# Number of clusters =  30
# Number of members in each cluster (not including noise)=  [  19   40    6  312   27   10   38    8   27  120    5 1860 1362    5
#     9    9   10  210   32   65   86   14   25    7   67    6    9   10
#    14   11]

# %%
plot_dbscan(model, X_scaled, size=100)

# %% [markdown]
# ### The clusters you identified are "statistical overdensities" which may or may not be real open clusters. In order to confirm that these overdensities are indeed open clusters, one will have to look at photometric and/or spectroscopic properties of the stars. We are not going to do this in this homework, but see the following papers if you are interested in.
#
# https://ui.adsabs.harvard.edu/abs/2019A%26A...627A..35C/abstract
#
# https://ui.adsabs.harvard.edu/abs/2020A%26A...640A...1C/abstract
#
# https://ui.adsabs.harvard.edu/abs/2022A%26A...661A.118C/abstract

# %% [markdown]
# ### 2. PCA and Neural Networks (6 pts)

# %% [markdown]
# In this homework problem, we will build a neural network that classifies galaxies based on their SDSS spectra (absorption galaxy, normal galaxy, emission galaxy). Let's first read in SDSS spectra. You can find the data file in the HiPerGator class share folder as well as on Canvas.

# %%
import numpy as np

data = np.load('sdss_spectra.npz')
data.files
# Out:
# ['wavelengths', 'X', 'y', 'labels', 'z']

# %% [markdown]
# The data contains the wavelengths (wavelengths), 3794 spectra (X), classification in integer (y), classification in string (labels), and redshift (z). Let's inspect the data.

# %%
data['wavelengths']
# Out:
# array([3162.2776, 3165.1917, 3168.1082, 3171.0273, 3173.9495, 3176.874 ,
#        3179.8015, 3182.7314, 3185.6643, 3188.5996, 3191.5378, 3194.4788,
#        3197.4224, 3200.3687, 3203.3176, 3206.2693, 3209.2239, 3212.181 ,
#        3215.1409, 3218.1035, 3221.0688, 3224.0369, 3227.0076, 3229.9812,
#        3232.9575, 3235.9365, 3238.9185, 3241.9028, 3244.8901, 3247.8801,
#        3250.873 , 3253.8684, 3256.867 , 3259.868 , 3262.8718, 3265.8784,
#        3268.8877, 3271.9   , 3274.9148, 3277.9324, 3280.953 , 3283.976 ,
#        3287.0022, 3290.031 , 3293.0627, 3296.0972, 3299.1343, 3302.1743,
#        3305.2173, 3308.2627, 3311.3113, 3314.3625, 3317.4165, 3320.4734,
#        3323.533 , 3326.5955, 3329.661 , 3332.729 , 3335.8   , 3338.8738,
#        3341.9504, 3345.0298, 3348.112 , 3351.1973, 3354.2854, 3357.3762,
#        3360.4697, 3363.5664, 3366.6658, 3369.768 , 3372.873 , 3375.981 ,
#        3379.0918, 3382.2056, 3385.322 , 3388.4417, 3391.564 , 3394.689 ,
#        3397.8171, 3400.948 , 3404.0818, 3407.2185, 3410.3582, 3413.5007,
#        3416.6462, 3419.7944, 3422.9456, 3426.0996, 3429.2568, 3432.4167,
#        3435.5796, 3438.745 , 3441.9138, 3445.0854, 3448.26  , 3451.4375,
#        3454.6177, 3457.801 , 3460.9873, 3464.1765, 3467.3684, 3470.5635,
#        3473.7615, 3476.9624, 3480.1663, 3483.373 , 3486.583 , 3489.7957,
#        3493.0115, 3496.23  , 3499.4517, 3502.6763, 3505.9038, 3509.1343,
#        3512.368 , 3515.6045, 3518.844 , 3522.0864, 3525.3318, 3528.5803,
#        3531.8318, 3535.0862, 3538.3435, 3541.604 , 3544.8674, 3548.1338,
#        3551.4033, 3554.6758, 3557.9514, 3561.2297, 3564.5112, 3567.796 ,
#        3571.0835, 3574.374 , 3577.6677, 3580.9644, 3584.2642, 3587.567 ,
#        3590.8726, 3594.1814, 3597.4934, 3600.8083, 3604.1262, 3607.4473,
#        3610.7715, 3614.0986, 3617.429 , 3620.7622, 3624.0986, 3627.438 ,
#        7870.458 , 7877.71  , 7884.969 , 7892.235 , 7899.5073, 7906.786 ,
#        7914.0723, 7921.3647, 7928.6636, 7935.9697], dtype=float32)

# %%
data['X']
# Out:
# array([[ 4.9201283,  5.1662374,  6.073041 , ...,  7.5093303,  7.970523 ,
#          7.9843907],
#        [ 2.189293 ,  2.1868663,  2.1844583, ..., 12.837092 , 12.934673 ,
#         12.810533 ],
#        [ 2.7451353,  2.738469 ,  3.368032 , ...,  9.2907915,  9.108875 ,
#          8.385379 ],
#        ...,
#        [ 1.7720324,  2.0300677,  2.2360272, ...,  4.777608 ,  7.0639305,
#          5.7977986],
#        [ 4.4983783,  5.072573 ,  5.6672626, ..., 21.518795 , 19.828224 ,
#         20.714499 ],
#        [ 3.9174566,  4.1198335,  5.0055575, ..., 14.062734 , 16.002117 ,
#         15.691873 ]], dtype=float32)

# %%
data['X'].shape
# Out:
# (3794, 1000)

# %%
data['y']
# Out:
# array([2, 1, 1, ..., 2, 0, 2], dtype=int32)

# %%
np.unique(data['y'])
# Out:
# array([0, 1, 2], dtype=int32)

# %%
data['labels']
# Out:
# array(['absorption galaxy', 'galaxy', 'emission galaxy'], dtype='<U17')

# %% [markdown]
# Let's standardize the data and make a plot showing the averaged spectrum of each class.

# %%
import sklearn
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

X = data['X']
y = data['y']
Xs = StandardScaler().fit_transform(X)

plt.plot(data['wavelengths'], np.mean(Xs[y == 0,:],axis=0), label='absorption galaxy')
plt.plot(data['wavelengths'], np.mean(Xs[y == 1,:],axis=0)+1, label='normal galaxy')
plt.plot(data['wavelengths'], np.mean(Xs[y == 2,:],axis=0)+2, label='emission galaxy')
plt.xlabel('wavelength (Angstroms)')
plt.ylabel('flux + offset')
plt.legend();

# %% [markdown]
# (a) Now that we have inspected the data, let's build a neural network. Using ```tensorflow.keras```, build a neural network that has **two hidden layers** each of which has **1,000 neurons**. It's always a good practice to check the model summary. Compile the model using **loss="sparse_categorical_crossentropy", Adam optimizer, and learning rate = 1.0e-3.** Then, train the model for **100 epochs**. Record the time it took for training. (1 pt)

# %%
import tensorflow.keras as keras

# Build the neural network
model = keras.models.Sequential([
    keras.layers.Input(shape=Xs.shape[1]),
    keras.layers.Dense(1000, activation='relu'),
    keras.layers.Dense(1000, activation='relu',),
    keras.layers.Dense(np.unique(y).shape[0], activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 1000)              1001000
#
#  dense_13 (Dense)            (None, 1000)              1001000
#
#  dense_14 (Dense)            (None, 3)                 3003
#
# =================================================================
# Total params: 2,005,003
# Trainable params: 2,005,003
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model before fitting to the data
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=keras.optimizers.Adam(learning_rate=1e-3),
              metrics='accuracy')

# %%
import time

# Start the clock
tstart = time.time()

# Fit the model to the data and store loss, accuracy, etc. in "history"
history = model.fit(Xs, y, epochs=100, validation_split=0.2)

ttrain = time.time()-tstart
# Out:
# Epoch 1/100
# 95/95 [==============================] - 2s 19ms/step - loss: 1.0065 - accuracy: 0.6521 - val_loss: 0.7363 - val_accuracy: 0.6456
# Epoch 2/100
# 95/95 [==============================] - 2s 18ms/step - loss: 0.6716 - accuracy: 0.6946 - val_loss: 0.5824 - val_accuracy: 0.7049
# Epoch 3/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.6681 - accuracy: 0.6820 - val_loss: 0.6119 - val_accuracy: 0.6377
# Epoch 4/100
# 95/95 [==============================] - 2s 18ms/step - loss: 0
100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.3668 - accuracy: 0.8329 - val_loss: 0.8061 - val_accuracy: 0.6403
# Epoch 96/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.3768 - accuracy: 0.8273 - val_loss: 0.6745 - val_accuracy: 0.6996
# Epoch 97/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.3846 - accuracy: 0.8214 - val_loss: 0.6915 - val_accuracy: 0.7101
# Epoch 98/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.3445 - accuracy: 0.8448 - val_loss: 0.6947 - val_accuracy: 0.6943
# Epoch 99/100
# 95/95 [==============================] - 2s 18ms/step - loss: 0.3312 - accuracy: 0.8514 - val_loss: 0.8225 - val_accuracy: 0.6838
# Epoch 100/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.3282 - accuracy: 0.8507 - val_loss: 0.7504 - val_accuracy: 0.7194

# %%
print('Training time = ',ttrain,'seconds = ',ttrain/60,'minutes')
# Out:
# Training time =  163.93644881248474 seconds =  2.7322741468747456 minutes

# %% [markdown]
# (b) Make plots showing training loss, validation loss, training accuracy, validation accuray. (1 pt)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(history.epoch, history.history['loss'], '.-', label='Loss')
plt.plot(history.epoch, history.history['val_loss'], '.-', label='Validation loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()


plt.subplot(1,2,2)
plt.plot(history.epoch, history.history['accuracy'], '.-', label='Accuracy')
plt.plot(history.epoch, history.history['val_accuracy'], '.-', label='Validation accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy score')
plt.legend();

# %% [markdown]
# (c) The original data lives in a 1,000 dimensional space. Let's reduce the dimension using PCA. Choose the number of PCs such that you preserve 99% of the variance in the original data. How many dimensions did you end up with? (1 pt)

# %%
# Looking at the original data
Xs = pd.DataFrame(Xs)
Xs
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.151005  0.125954  0.133412  0.183464  0.066499  0.162929  0.100337
# 1    -0.338373 -0.395093 -0.472775 -0.425277 -0.419020 -0.414372 -0.403857
# 2    -0.238763 -0.298626 -0.288269 -0.265920 -0.327568 -0.278817 -0.296214
# 3    -0.164831 -0.183833 -0.143598 -0.195498 -0.146428 -0.133342 -0.181548
# 4    -0.469687 -0.513288 -0.491658 -0.517128 -0.539567 -0.511834 -0.515375
# ...        ...       ...       ...       ...       ...       ...       ...
# 3789 -0.629184 -0.636475 -0.645170 -0.585302 -0.650958 -0.608954 -0.644959
# 3790 -0.458878 -0.223446 -0.453432 -0.255315 -0.453055 -0.696520 -0.338931
# 3791 -0.413148 -0.422514 -0.464736 -0.429195 -0.502656 -0.489745 -0.437915
# 3792  0.075425  0.109573  0.070156  0.139979  0.111729  0.106579  0.101125
# 3793 -0.028678 -0.057046 -0.032997 -0.081851 -0.083062 -0.062317 -0.060493
#
#            7         8         9    ...       990       991       992  \
# 0     0.185328  0.184928  0.159102  ... -0.607258 -0.626090 -0.594101
# 1    -0.385108 -0.387263 -0.404069  ... -0.293443 -0.292840 -0.293811
# 2    -0.225589 -0.240709 -0.263400  ... -0.504016 -0.504713 -0.504453
# 3    -0.169629 -0.160184 -0.149285  ...  0.281107  0.236121  0.266773
# 4    -0.460954 -0.450104 -0.481056  ... -0.486154 -0.486250 -0.487492
# ...        ...       ...       ...  ...       ...       ...       ...
# 3789 -0.586409 -0.598382 -0.617831  ... -0.757765 -0.744849 -0.772938
# 3790 -0.377083 -0.188394 -0.403210  ... -0.708137 -0.710207 -0.711152
# 3791 -0.410872 -0.401672 -0.448429  ... -0.773654 -0.767148 -0.766240
# 3792  0.078685  0.048249  0.069491  ...  0.129157  0.181064  0.206501
# 3793 -0.041977 -0.020532 -0.039366  ... -0.124551 -0.135180 -0.133435
#
#            993       994       995       996       997       998       999
# 0    -0.604483 -0.585238 -0.602815 -0.553836 -0.647424 -0.621833 -0.613848
# 1    -0.294102 -0.293204 -0.294964 -0.293477 -0.294205 -0.293781 -0.293058
# 2    -0.488263 -0.508189 -0.412929 -0.564302 -0.529317 -0.546606 -0.587194
# 3     0.212663  0.280638  0.255129  0.176899  0.239103  0.201728  0.168287
# 4    -0.485472 -0.485203 -0.491669 -0.496153 -0.440482 -0.548911 -0.517269
# ...        ...       ...       ...       ...       ...       ...       ...
# 3789 -0.795027 -0.740460 -0.797885 -0.743256 -0.780018 -0.781811 -0.773128
# 3790 -0.711672 -0.711398 -0.712575 -0.711622 -0.712879 -0.715213 -0.712593
# 3791 -0.768149 -0.769509 -0.766930 -0.721361 -0.828531 -0.681745 -0.759189
# 3792  0.161441  0.174702  0.218076  0.300010  0.281371  0.161774  0.232312
# 3793 -0.148740 -0.143615 -0.118420 -0.210620 -0.212948 -0.091071 -0.101538
#
# [3794 rows x 1000 columns]

# %%
from sklearn.decomposition import PCA
import pandas as pd

# Apply PCA with 99% variance
pca = PCA(n_components=0.99)
X_pca = pca.fit_transform(Xs)
X_pca = pd.DataFrame(X_pca)
X_pca
# Out:
#               0         1         2         3
# 0    -10.547617 -6.229943  3.917347  1.391055
# 1    -12.438126  2.042567 -3.089571 -0.070129
# 2    -17.427879 -0.932858 -1.485168 -0.246767
# 3     -0.952841  3.281382 -5.601580 -0.358503
# 4    -19.114012  1.289889 -2.596390 -0.344458
# ...         ...       ...       ...       ...
# 3789 -17.745779 -0.613411  5.880162 -1.048424
# 3790 -21.985241 -0.598070 -0.913424  0.267932
# 3791 -19.720570 -1.951530  2.235581 -0.585173
# 3792   4.808682  0.786770 -1.835710  0.309919
# 3793  -6.097070 -0.713416 -1.029043  0.009989
#
# [3794 rows x 4 columns]

# %%
print('Number of dimensions after PCA = ', pca.n_components_)
# Out:
# Number of dimensions after PCA =  4

# %% [markdown]
# (d) Make a plot showing the averaged inverse transformed spectrum of each class. How do they compare with the plot you made earlier? (1 pt)

# %%
inverse = pca.inverse_transform(X_pca)
inverse.shape, Xs.shape
# Out:
# ((3794, 1000), (3794, 1000))

# %%
plt.figure(figsize=(8,6))

plt.subplot(2,1,1)
plt.plot(data['wavelengths'], np.mean(inverse[y == 0,:],axis=0), label='absorption galaxy')
plt.plot(data['wavelengths'], np.mean(inverse[y == 1,:],axis=0)+1, label='normal galaxy')
plt.plot(data['wavelengths'], np.mean(inverse[y == 2,:],axis=0)+2, label='emission galaxy')
plt.xlabel('wavelength (Angstroms)')
plt.ylabel('flux + offset')
plt.legend()
plt.title('Inverse Transformed Spectrum')

plt.subplot(2,1,2)
X = data['X']
y = data['y']
Xs = StandardScaler().fit_transform(X)

plt.plot(data['wavelengths'], np.mean(Xs[y == 0,:],axis=0), label='absorption galaxy')
plt.plot(data['wavelengths'], np.mean(Xs[y == 1,:],axis=0)+1, label='normal galaxy')
plt.plot(data['wavelengths'], np.mean(Xs[y == 2,:],axis=0)+2, label='emission galaxy')
plt.xlabel('wavelength (Angstroms)')
plt.ylabel('flux + offset')
plt.legend()
plt.title('Original Spectrum')

plt.tight_layout(pad=2);

# %% [markdown]
# **The inverse transformed spectrum looks very similar to the original spectrum for all 3 classes.**

# %% [markdown]
# (e) Build a new neural network, using the same architecture, optimizer, learning rate, number of epochs as in (a), and train it. How does the number of trainable parameters compare? How does the training time compare? Do you see the benefit of PCA? (1 pt)

# %%
# Build the neural network
model = keras.models.Sequential([
    keras.layers.Input(shape=X_pca.shape[1]),
    keras.layers.Dense(1000, activation='relu'),
    keras.layers.Dense(1000, activation='relu',),
    keras.layers.Dense(np.unique(y).shape[0], activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 1000)              5000
#
#  dense_10 (Dense)            (None, 1000)              1001000
#
#  dense_11 (Dense)            (None, 3)                 3003
#
# =================================================================
# Total params: 1,009,003
# Trainable params: 1,009,003
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model before fitting to the data
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=keras.optimizers.Adam(learning_rate=1e-3),
              metrics='accuracy')

# %%
import time

# Start the clock
tstart = time.time()

# Fit the model to the data and store loss, accuracy, etc. in "history"
history = model.fit(X_pca, y, epochs=100, validation_split=0.2)

ttrain = time.time()-tstart
# Out:
# Epoch 1/100
# 95/95 [==============================] - 2s 13ms/step - loss: 0.9461 - accuracy: 0.6728 - val_loss: 0.6643 - val_accuracy: 0.6653
# Epoch 2/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.6322 - accuracy: 0.7081 - val_loss: 0.6233 - val_accuracy: 0.6719
# Epoch 3/100
# 95/95 [==============================] - 1s 13ms/step - loss: 0.6003 - accuracy: 0.7091 - val_loss: 0.7264 - val_accuracy: 0.6298
# Epoch 4/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5792 - accuracy: 0.7328 - val_loss: 0.6166 - val_accuracy: 0.6706
# Epoch 5/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5774 - accuracy: 0.7153 - val_loss: 0.5997 - val_accuracy: 0.6957
# Epoch 6/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5774 - accuracy: 0.7170 - val_loss: 0.6321 - val_accuracy: 0.6653
# Epoch 7/100
# 95/95 [==============================] - 1s 13ms/step - loss: 0.5679 - accuracy: 0.7170 - val_loss: 0.6369 - val_accuracy: 0.6601
# Epoch 8/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.5625 - accuracy: 0.7236 - val_loss: 0.6123 - val_accuracy: 0.6614
# Epoch 9/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5625 - accuracy: 0.7189 - val_loss: 0.6026 - val_accuracy: 0.6798
# Epoch 10/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5671 - accuracy: 0.7226 - val_loss: 0.6001 - val_accuracy: 0.6930
# Epoch 11/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.5507 - accuracy: 0.7245 - val_loss: 0.5985 - val_accuracy: 0.6930
# Epoch 12/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.5518 - accuracy: 0.7236 - val_loss: 0.5987 - val_accuracy: 0.6772
# Epoch 13/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5412 - accuracy: 0.7334 - val_loss: 0.5963 - val_accuracy: 0.6798
# Epoch 14/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5394 - accuracy: 0.7325 - val_loss: 0.5887 - val_accuracy: 0.7075
# Epoch 15/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.5421 - accuracy: 0.7189 - val_loss: 0.5977 - val_accuracy: 0.6640
# Epoch 16/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5388 - accuracy: 0.7262 - val_loss: 0.6103 - val_accuracy: 0.6693
# Epoch 17/100
# 95/95 [==============================] - 1s 13ms/step - loss: 0.5427 - accuracy: 0.7298 - val_loss: 0.6349 - val_accuracy: 0.6746
# Epoch 18/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.5359 - accuracy: 0.7269 - val_loss: 0.5858 - val_accuracy: 0.7154
# Epoch 19/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5335 - accuracy: 0.7292 - val_loss: 0.6001 - val_accuracy: 0.6864
# Epoch 20/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5365 - accuracy: 0.7321 - val_loss: 0.5898 - val_accuracy: 0.6970
# Epoch 21/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5316 - accuracy: 0.7272 - val_loss: 0.5920 - val_accuracy: 0.6930
# Epoch 22/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.5551 - accuracy: 0.7236 - val_loss: 0.5943 - val_accuracy: 0.6943
# Epoch 23/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5441 - accuracy: 0.7282 - val_loss: 0.5961 - val_accuracy: 0.7022
# Epoch 24/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5365 - accuracy: 0.7308 - val_loss: 0.5940 - val_accuracy: 0.6943
# Epoch 25/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.5266 - accuracy: 0.7315 - val_loss: 0.6015 - val_accuracy: 0.6851
# Epoch 26/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.5346 - accuracy: 0.7325 - val_loss: 0.5905 - val_accuracy: 0.6838
# Epoch 27/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5314 - accuracy: 0.7282 - val_loss: 0.6066 - val_accuracy: 0.6825
# Epoch 28/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.5249 - accuracy: 0.7341 - val_loss: 0.6138 - val_accuracy: 0.6680
# Epoch 29/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.5243 - accuracy: 0.7229 - val_loss: 0.6453 - val_accuracy: 0.6706
# Epoch 30/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5190 - accuracy: 0.7325 - val_loss: 0.5952 - val_accuracy: 0.6983
# Epoch 31/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5233 - accuracy: 0.7308 - val_loss: 0.6144 - val_accuracy: 0.6943
# Epoch 32/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5240 - accuracy: 0.7301 - val_loss: 0.6034 - val_accuracy: 0.6957
# Epoch 33/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5188 - accuracy: 0.7341 - val_loss: 0.5986 - val_accuracy: 0.7049
# Epoch 34/100
# 95/95 [==============================] - 1s 13ms/step - loss: 0.5207 - accuracy: 0.7288 - val_loss: 0.6050 - val_accuracy: 0.6825
# Epoch 35/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.5274 - accuracy: 0.7301 - val_loss: 0.6043 - val_accuracy: 0.6706
# Epoch 36/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5206 - accuracy: 0.7341 - val_loss: 0.5969 - val_accuracy: 0.6838
# Epoch 37/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5146 - accuracy: 0.7390 - val_loss: 0.6065 - val_accuracy: 0.6891
# Epoch 38/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.5196 - accuracy: 0.7348 - val_loss: 0.5997 - val_accuracy: 0.6785
# Epoch 39/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.5234 - accuracy: 0.7351 - val_loss: 0.6267 - val_accuracy: 0.6733
# Epoch 40/100
# 95/95 [==============================] - 1s 13ms/step - loss: 0.5209 - accuracy: 0.7288 - val_loss: 0.6287 - val_accuracy: 0.6746
# Epoch 41/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.5081 - accuracy: 0.7367 - val_loss: 0.6210 - val_accuracy: 0.6904
# Epoch 42/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5172 - accuracy: 0.7269 - val_loss: 0.6244 - val_accuracy: 0.6812
# Epoch 43/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5163 - accuracy: 0.7410 - val_loss: 0.6393 - val_accuracy: 0.6746
# Epoch 44/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.5093 - accuracy: 0.7351 - val_loss: 0.6206 - val_accuracy: 0.6785
# Epoch 45/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.5132 - accuracy: 0.7361 - val_loss: 0.6250 - val_accuracy: 0.6746
# Epoch 46/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.5057 - accuracy: 0.7400 - val_loss: 0.6171 - val_accuracy: 0.6719
# Epoch 47/100
# 95/95 [==============================] - 1s 13ms/step - loss: 0.5057 - accuracy: 0.7364 - val_loss: 0.6260 - val_accuracy: 0.6772
# Epoch 48/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.5016 - accuracy: 0.7390 - val_loss: 0.6337 - val_accuracy: 0.6693
# Epoch 49/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.4996 - accuracy: 0.7417 - val_loss: 0.6406 - val_accuracy: 0.6838
# Epoch 50/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.
100
# 95/95 [==============================] - 1s 13ms/step - loss: 0.4635 - accuracy: 0.7684 - val_loss: 0.6895 - val_accuracy: 0.6733
# Epoch 81/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.4611 - accuracy: 0.7707 - val_loss: 0.6833 - val_accuracy: 0.6785
# Epoch 82/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.4537 - accuracy: 0.7750 - val_loss: 0.6965 - val_accuracy: 0.6588
# Epoch 83/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.4577 - accuracy: 0.7651 - val_loss: 0.7064 - val_accuracy: 0.6667
# Epoch 84/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.4572 - accuracy: 0.7710 - val_loss: 0.6882 - val_accuracy: 0.6904
# Epoch 85/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.4547 - accuracy: 0.7694 - val_loss: 0.7295 - val_accuracy: 0.6812
# Epoch 86/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.4637 - accuracy: 0.7680 - val_loss: 0.7055 - val_accuracy: 0.6798
# Epoch 87/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.4646 - accuracy: 0.7667 - val_loss: 0.7057 - val_accuracy: 0.6772
# Epoch 88/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.4624 - accuracy: 0.7631 - val_loss: 0.7357 - val_accuracy: 0.6495
# Epoch 89/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.4568 - accuracy: 0.7700 - val_loss: 0.7054 - val_accuracy: 0.6693
# Epoch 90/100
# 95/95 [==============================] - 1s 13ms/step - loss: 0.4511 - accuracy: 0.7687 - val_loss: 0.7198 - val_accuracy: 0.6667
# Epoch 91/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.4486 - accuracy: 0.7776 - val_loss: 0.7179 - val_accuracy: 0.6627
# Epoch 92/100
# 95/95 [==============================] - 1s 13ms/step - loss: 0.4437 - accuracy: 0.7763 - val_loss: 0.7318 - val_accuracy: 0.6693
# Epoch 93/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.4535 - accuracy: 0.7736 - val_loss: 0.7143 - val_accuracy: 0.6759
# Epoch 94/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.4401 - accuracy: 0.7769 - val_loss: 0.7310 - val_accuracy: 0.6706
# Epoch 95/100
# 95/95 [==============================] - 1s 13ms/step - loss: 0.4407 - accuracy: 0.7763 - val_loss: 0.7403 - val_accuracy: 0.6653
# Epoch 96/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.4436 - accuracy: 0.7733 - val_loss: 0.7579 - val_accuracy: 0.6851
# Epoch 97/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.4441 - accuracy: 0.7769 - val_loss: 0.7317 - val_accuracy: 0.6746
# Epoch 98/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.4469 - accuracy: 0.7727 - val_loss: 0.7528 - val_accuracy: 0.6838
# Epoch 99/100
# 95/95 [==============================] - 1s 12ms/step - loss: 0.4457 - accuracy: 0.7766 - val_loss: 0.7620 - val_accuracy: 0.6706
# Epoch 100/100
# 95/95 [==============================] - 1s 11ms/step - loss: 0.4446 - accuracy: 0.7779 - val_loss: 0.7470 - val_accuracy: 0.6640

# %%
print('Training time = ',ttrain,'seconds = ',ttrain/60,'minutes')
# Out:
# Training time =  112.52966165542603 seconds =  1.875494360923767 minutes

# %% [markdown]
# **With the PCA model, the number of training parameters was reduced by 50% and the training time was reduced by more than 50%. These two improvements demonstrate the benefit of PCA.**

# %% [markdown]
# (f) Make plots showing training loss, validation loss, training accuracy, validation accuray, similar to (b). Did you get a comparable accucary? (1 pt)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(history.epoch, history.history['loss'], '.-', label='Loss')
plt.plot(history.epoch, history.history['val_loss'], '.-', label='Validation loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()


plt.subplot(1,2,2)
plt.plot(history.epoch, history.history['accuracy'], '.-', label='Accuracy')
plt.plot(history.epoch, history.history['val_accuracy'], '.-', label='Validation accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy score')
plt.legend()

plt.suptitle('PCA data')
plt.tight_layout(pad=2);

# %% [markdown]
# **Accuracy is similar to before.**
